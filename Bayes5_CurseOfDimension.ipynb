# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.special import gamma
# %matplotlib inline

# %%
plt.style.use("ggplot")
np.random.seed(123)
accept_dict = {}

# %%
NMCS = 40000
Ndim = 5
accept = 0

for i in range(NMCS):
    x = 2 * np.random.rand(Ndim) - 1.0
    r = (np.sum(x**2)) ** 0.5
    if r <= 1:
        accept += 1

accept_ratio = accept/NMCS
analytical = np.pi **(Ndim/2) / (2**Ndim * gamma(Ndim/2 + 1))
print("Accepti raio: ", accept_ratio)
print("Analytical solution: ", analytical)
accept_dict.update({Ndim:accept_ratio / analytical})

# print(x)
# plt.hist(x, bins=int(np.sqrt(Ndim)))
# Out:
# Accepti raio:  0.164825
# Analytical solution:  0.16449340668482262

# %%
NMCS = 40000
Ndim = np.arange(1,16)

accept_ratio = []
analytical = []

for j in Ndim:
    accept = 0
    for i in range(NMCS):
        x = 2 * np.random.rand(Ndim[j-1]) - 1.0
        r = (np.sum(x**2)) ** 0.5
        if r <= 1:
            accept += 1

    accept_ratio.append(accept/NMCS)
    analytical.append(np.pi **(Ndim[j-1]/2) / (2**Ndim[j-1] * gamma(Ndim[j-1]/2 + 1)))

print("Accepti raio: ", accept_ratio)
print("Analytical solution: ", analytical)
# accept_dict.update({Ndim:accept_ratio / analytical})

# print(x)
# plt.hist(x, bins=int(np.sqrt(Ndim)))

accept_ratio = np.array(accept_ratio)
analytical = np.array(analytical)
# Out:
# Accepti raio:  [1.0, 0.786525, 0.524925, 0.309025, 0.166875, 0.080425, 0.037075, 0.01595, 0.006125, 0.002475, 0.000925, 0.000275, 0.0001, 0.0, 0.0]
# Analytical solution:  [1.0, 0.7853981633974483, 0.5235987755982989, 0.30842513753404244, 0.16449340668482262, 0.08074551218828077, 0.03691223414321407, 0.0158543442438155, 0.006442400200661536, 0.00249039457019272, 0.0009199725973583495, 0.00032599188692738996, 0.00011116073666788121, 3.657620418217724e-05, 1.1640725122781505e-05]

# %%
plt.scatter(Ndim, accept_ratio/analytical)
plt.xlabel("Dimension")
plt.ylabel("Ratio[-]")
# Out:
# Text(0, 0.5, 'Ratio[-]')
